# %% [markdown]
# <a href="https://colab.research.google.com/github/2403a52208-sudo/NLP/blob/main/2403A52208_B09_assg_16.4_ipynab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Hugging Face library

# %%
# !pip install transformers datasets

# %% [markdown]
# Import Libraries

# %%
from transformers import pipeline

# %% [markdown]
# Sentiment Analysis

# %% [markdown]
# This line automatically:
#
# Downloads model Loads tokenizer Initializes pipeline

# %%
classifier = pipeline("sentiment-analysis")

result = classifier("Hugging Face is very easy to use!")
print(result)

# %% [markdown]
# Dataset Importing

# %%
from datasets import load_dataset
dataset = load_dataset("imdb")
print(dataset)

# %% [markdown]
# Part 2: Using BERT Model,
# Load Tokenizer & Model

# %%
from transformers import AutoTokenizer, AutoModel

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
model = AutoModel.from_pretrained("bert-base-uncased")

# %%
text = "Hugging Face is a great platform!"

inputs = tokenizer(text,return_tensors="pt")
print(inputs)

# %%
outputs = model(**inputs)

# CLS token embedding
cls_embedding = outputs.last_hidden_state[:, 0, :]
print(cls_embedding.shape)

# %% [markdown]
# Text Classification Using Hugging Face With Sample Data

# %%
from transformers import AutoTokenizer, AutoModel
import torch
import numpy as np
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split

# %%
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
model = AutoModel.from_pretrained("bert-base-uncased")

# %%
texts = [
    "urgent call now",
    "free gift waiting",
    "how was your day",
    "let's go for lunch",
    "win a free ticket",
    "are you coming today"
]
labels = [1, 1, 1, 0, 0, 0]

# %%
def get_embedding(text):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True)

    outputs = model(**inputs)

    # CLS embedding
    cls_embedding = outputs.last_hidden_state[:, 0, :]

    return cls_embedding.detach().numpy()[0]

# %%
X = np.array([get_embedding(t) for t in texts])
y = np.array(labels)
print("Feature shape:", X.shape)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
clf = GaussianNB()
clf.fit(X_train, y_train)

# %%
y_pred = clf.predict(X_test)

print("Predictions:", y_pred)
print("Actual:", y_test)

# %%
test_text = "This product is really good"

test_emb = get_embedding(test_text).reshape(1, -1)

prediction = clf.predict(test_emb)

print("Prediction:", "Positive" if prediction[0] == 1 else "Negative")
